# %% [markdown]
# # Answers to Comments 3 part 2 Segmenation

# %%
## the data are 1mm thin slices. How does this method work on thick slice data (>3mm).

# %% [markdown]
# ## imports

# %%
# libraries
import os
import re
import glob
import numpy as np
import matplotlib.pyplot as plt

# custom

from Dense_Unet_Seg import *
from data_3D_utilities import *

# %% [markdown]
# ## Path Setting

# %%
#Windows
#rootPath = "E:/Dataset from SpineWeb/Dataset2-Jack"
#Linux
rootPath = '/home/shu/Dataset/TestHealthyCases/Resample8'
SrcmhdFolder = '/Resample1' #'/Resample'

# %% [markdown]
# # 3D-Dense-U-Net 结果评价

# %% [markdown]
# ## Input and Output based on GT Centroids

# %%
# cases to ROI,labels to ROI

#获得cases和labels所在的文件所有路径
cases = sorted(glob(rootPath + SrcmhdFolder + '/images/*.mhd'))#[0:1]
labels = sorted(glob(rootPath + SrcmhdFolder + '/masks/*.mhd'))#[0:1]
i = 0
for case in cases:
    filename = re.sub(r'.mhd', '',os.path.split(case)[1]) + '_label'
    centroids = np.loadtxt(rootPath + SrcmhdFolder + '/Centroids/IJK/' + filename +'.csv',delimiter = ',')
    outPath = rootPath + SrcmhdFolder + '/ROI/test/images/' + filename + "/"
    
    FindROI3D(case,outPath,centroids,0,4095,False,True,True,True)
    i+=1
    
i = 0    
for label in labels:
    filename = re.sub(r'.mhd', '',os.path.split(label)[1])
    centroids = np.loadtxt(rootPath + SrcmhdFolder + '/Centroids/IJK/' + filename +'.csv',delimiter = ',')
    outPath = rootPath + SrcmhdFolder + '/ROI/test/masks/' + filename + "/"
    
    FindROI3D(label,outPath,centroids,0,4095,True,True,True,True)
    i+=1
# Out:
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900]
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900]
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# [   0  200  300  400  500  600  700  800  900 1000 1100 1200 1300 1400
#  1500 1600 1700 1800]
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# [   0  200  300  400  500  600  700  800  900 1000 1100 1200 1300 1400
#  1500 1600 1700 1800 1900]
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# [   0  200  300  400  500  600  700  800  900 1000 1100 1200 1300 1400
#  1500 1600 1700 1800]
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800

# %%
cases
# Out:
# ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/images/Resmpl_Resmpl_case18.mhd',
#  '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/images/Resmpl_Resmpl_case19.mhd',
#  '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/images/Resmpl_Resmpl_case20.mhd',
#  '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/images/Resmpl_Resmpl_case22.mhd',
#  '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/images/Resmpl_Resmpl_case23.mhd']

# %% [markdown]
# ## predict

# %%
# 设置用于训练的GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# The GPU id to use, usually either "0" or "1"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
test_cases_folders = sorted(os.listdir(rootPath + SrcmhdFolder + '/ROI/test/images/'))#[0:1]
test_labels_folders = sorted(os.listdir(rootPath + SrcmhdFolder + '/ROI/test/masks/'))#[0:1]

# %%
# 依次加载测试数据集并预测
i = 0
for testfile in test_cases_folders:
    casesPath = rootPath + SrcmhdFolder + '/ROI/test/images/' + testfile + '/*.bin'
    labelsPath = rootPath + SrcmhdFolder + '/ROI/test/masks/' + test_labels_folders[i] + '/*.bin'
    # print(casesPath,labelsPath)
    dataset_test = dataset_test_build(casesPath,labelsPath)

    # 预测测试结果
    weight_dir = os.path.join('weights', '3D-Dense-Unet-Ins-20210403-104846' + '.h5')
    outPath = rootPath + SrcmhdFolder + "/pred_ROI/" + "pred_" + testfile + "/"
    predict(weight_dir,dataset_test,outPath,0.5)
    i = i + 1
# Out:
# ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case18_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case18_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case18_label/016.bin'] ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case18_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case18_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case18_label/016.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 1s 538ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 252ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 255ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 264ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 260ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 251ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 253ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 260ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case19_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case19_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case19_label/016.bin'] ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case19_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case19_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case19_label/016.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 500ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 279ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 260ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 261ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 253ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case20_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case20_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case20_label/016.bin'] ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case20_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case20_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case20_label/016.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 1s 574ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 261ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 265ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 260ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 255ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case22_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case22_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case22_label/016.bin'] ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case22_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case22_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case22_label/016.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 484ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 261ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 271ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 261ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 256ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 255ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 260ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case23_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case23_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/images/Resmpl_Resmpl_case23_label/016.bin'] ['/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case23_label/014.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case23_label/015.bin', '/home/shu/Dataset/TestHealthyCases/Resample8/Resample1/ROI/test/masks/Resmpl_Resmpl_case23_label/016.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 486ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 269ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 263ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 254ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 265ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 255ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 258ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 259ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 263ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 260ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 265ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 262ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 257ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 255ms/step
# ------------------------------
# Prediction finished
# ------------------------------

# %% [markdown]
# ## Eval Seg Results

# %%
# 定义评价指标:
EvalDict = {'DICE':0,'JACRD':0,'HDRFDST':0,'ACURCY':0}

# %%
GTROIPath = rootPath + SrcmhdFolder + '/ROI/test/masks/'
predROIPath = rootPath + SrcmhdFolder + '/pred_ROI/'

# %%
GTROIFolders = sorted(os.listdir(GTROIPath))#[4:5]
predROIFolders = sorted(os.listdir(predROIPath))#[4:5]

# %% [markdown]
# ### 获得评价指标对应结果

# %%
i = 0
EvalResultsDatas = []
for GTROIFolder in GTROIFolders:
    GTFolder = GTROIPath + GTROIFolder
    PredFolder = predROIPath + predROIFolders[i] + '/rmvsml'
    
    EvalResultsData = EvalResults(GTFolder,PredFolder,EvalDict)
#     EvalResultsData.index = ['T1','L1', 'L2', 'L3', 'L4', 'L5']
# 0  0.863275  0.759440   5.196152  0.995117
# 0  0.876747  0.780543   6.082763  0.995409
# 0  0.879643  0.785146   7.000000  0.995220
# 0  0.864366  0.761131   8.000000  0.993862
# 0  0.854160  0.745445  10.000000  0.992739
# 0  0.873027  0.774665   5.385165  0.993134
# 0  0.889365  0.800772   7.000000  0.993564
# 0  0.885014  0.793745   5.656854  0.991576
# 0  0.900206  0.818523   4.000000  0.992486
# 0  0.898351  0.815461   5.000000  0.991431
# 0  0.892781  0.806328   7.280110  0.989843
# 0  0.880958  0.787243   7.000000  0.990373
# 17 17
#        DICE     JACRD    HDRFDST    ACURCY
# 0  0.754059  0.605212   9.219544  0.992048
# 0  0.817808  0.691772   7.141428  0.993324
# 0  0.821334  0.696833  15.811388  0.992955
# 0  0.807366  0.676961  22.022716  0.992293
# 0  0.845582  0.732475  18.000000  0.993894
# 0  0.838737  0.722262  11.357817  0.992618
# 0  0.850078  0.739248   8.246211  0.993186
# 0  0.827786  0.706173   8.306624  0.991505
# 0  0.836855  0.719476   8.000000  0.990763
# 0  0.843408  0.729218  10.000000  0.989716
# 0  0.867732  0.766367   6.557439  0.990836
# 0  0.897405  0.813902   7.000000  0.992010
# 0  0.886768  0.796571   8.062258  0.989738
# 0  0.895707  0.811114   6.403124  0.989615
# 0  0.901853  0.821250   7.681146  0.989387
# 0  0.901557  0.820760  13.038405  0.989826
# 0  0.875265  0.778196  14.000000  0.987374

# %% [markdown]
# ### 所有椎体的DICE平均值

# %%
ResultsALL = pd.concat(EvalResultsDatas)

# %%
ResultsALL
# Out:
#         DICE     JACRD    HDRFDST    ACURCY
# 0   0.824503  0.701408   6.000000  0.996118
# 0   0.776170  0.634215  13.076697  0.995210
# 0   0.814764  0.687428   5.099020  0.996198
# 0   0.857497  0.750543  13.000000  0.996896
# 0   0.822066  0.697888   5.385165  0.995748
# ..       ...       ...        ...       ...
# 0   0.886768  0.796571   8.062258  0.989738
# 0   0.895707  0.811114   6.403124  0.989615
# 0   0.901853  0.821250   7.681146  0.989387
# 0   0.901557  0.820760  13.038405  0.989826
# 0   0.875265  0.778196  14.000000  0.987374
#
# [85 rows x 4 columns]

# %%
format(ResultsALL.DICE.mean(), '3f')
# Out:
# '0.858583'

# %%
format(ResultsALL.DICE.std(), '3f')
# Out:
# '0.035234'

# %% [markdown]
# ### Get Dice of L1-L5

# %%
# Get Mean Dice of L1-L5
L1 = []
L2 = []
L3 = []
L4 = []
L5 = []
for EvalResult in EvalResultsDatas:
    
    L1.append(EvalResult.DICE['L1'])
    L2.append(EvalResult.DICE['L2'])
    L3.append(EvalResult.DICE['L3'])
    L4.append(EvalResult.DICE['L4'])
    L5.append(EvalResult.DICE['L5'])

# %%
L = [L1,L2,L3,L4,L5]

# %%
MeanL = []
for L_idx in L:
    MeanL.append(format(np.array(L_idx).mean(), '.4f'))
print(MeanL)

# %%
0.8720277999999999
['0.8634', '0.8713', '0.8904', '0.8738', '0.8613']
