# %% [markdown]
# ## Configuration

# %% [markdown]
# ### imports

# %%
## imports

# libraries
import os
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# custom
from Dense_Unet_Seg import *

print(tf.__version__)
# Out:
# 2.4.0

# %%
# 设置用于训练的GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# The GPU id to use, usually either "0" or "1"
os.environ["CUDA_VISIBLE_DEVICES"]="1" #"1":train, "0":predict;

# %% [markdown]
# ### Path Setting

# %%
#Linux
rootPath = '/home/shu/Dataset/Dataset-xVertSeg'
SrcmhdFolder = '/Spilt' #'/Resample'

# %% [markdown]
# ## dataset_train, dataset_val构造

# %%
casestrainPath = rootPath + SrcmhdFolder + '/ROI/train/images/*/*.bin'
labelstrainPath = rootPath + SrcmhdFolder + '/ROI/train/masks/*/*.bin'

# %%
cases_train = sorted(glob(casestrainPath))
labels_train = sorted(glob(labelstrainPath))

# %%
len(labels_train)
# Out:
# 150

# %%
dataset_train, count_train = dataset_train_build(casestrainPath,labelstrainPath)
# Out:
# [ 42  22  80  13  28   0   8  30   2  43  35  73 113 115  91 125  55  69
#   23  66  61 112 134   4 133  65  74  72  12   6  81  97  34 132  58  68
#  104  24 143  56 146 105  45  64 129  83 149 136  59  88 108  16 118  39
#   92  29  67 127  77  46  48 107  37  96  99 144  60  47  26 142  98 122
#  117  79 103   3  20  32 139  18  87  95  31 100  86  75 126  84 119 114
#    9  51 131  27 135  50  89  17  78 137 111  11  53  76  40  15  90  82
#  147  19 121 145  36  10  25 141  41 138 148  71  14 106  38 130   5 120
#  140  52 123  54  49  63 124 110   1   7 101  33  70 102  93  21  62  44
#   94 109 128  57  85 116]
# ['/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/images_noisy/009.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/images_noisy/028.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/Splt_image006_etf/002.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/Splt_image009_etf/000.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/images_noisy/016.bin']
# ['/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/masks_noisy/009.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/masks_noisy/028.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/Splt_image006_etf/002.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/Splt_image009_etf/000.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/masks_noisy/016.bin']
# ['/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/Splt_image006_etf/002.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/Splt_image009_etf/000.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/images/images_noisy/016.bin'] ['/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/Splt_image006_etf/002.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/Splt_image009_etf/000.bin'
#  '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/train/masks/masks_noisy/016.bin']

# %%
casesvalPath = rootPath + SrcmhdFolder + '/ROI/test/images/*/*.bin'
labelsvalPath = rootPath + SrcmhdFolder + '/ROI/test/masks/*/*.bin'

# %%
dataset_val, count_val = dataset_val_build(casesvalPath,labelsvalPath)
# Out:
# ['/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/test/images/Splt_image015/002.bin', '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/test/images/Splt_image015/003.bin', '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/test/images/Splt_image015/004.bin'] ['/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/test/masks/Splt_image015/002.bin', '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/test/masks/Splt_image015/003.bin', '/home/shu/Dataset/Dataset xVertSeg/Spilt/ROI/test/masks/Splt_image015/004.bin']

# %%
STEPS_PER_EPOCH = count_train//BATCH_SIZE
VALIDATION_STEPS = count_val//BATCH_SIZE

# %%
dataset_train,dataset_val
# Out:
# (<PrefetchDataset shapes: ((None, 80, 128, 112), (None, 80, 128, 112)), types: (tf.float32, tf.float64)>,
#  <PrefetchDataset shapes: ((None, 80, 128, 112), (None, 80, 128, 112)), types: (tf.float32, tf.float64)>)

# %% [markdown]
# ## 3D-Dense-U-Net训练

# %%
train(dataset_train,dataset_val,EPOCHS,STEPS_PER_EPOCH,VALIDATION_STEPS)
# Out:
# ------------------------------
# Creating and compiling model...
# ------------------------------
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                 Output Shape                 Param #   Connected to
# ==================================================================================================
# input_1 (InputLayer)         [(None, 80, 128, 112, 1)]    0
# __________________________________________________________________________________________________
# conv3d (Conv3D)              (None, 80, 128, 112, 32)     896       input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)    (None, 80, 128, 112, 33)     0         input_1[0][0]
#                                                                     conv3d[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)            (None, 80, 128, 112, 32)     28544     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)  (None, 80, 128, 112, 33)     0         input_1[0][0]
#                                                                     conv3d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 40, 64, 56, 33)       0         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)            (None, 40, 64, 56, 64)       57088     max_pooling3d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)  (None, 40, 64, 56, 97)       0         max_pooling3d[0][0]
#                                                                     conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)            (None, 40, 64, 56, 64)       167680    concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)  (None, 40, 64, 56, 97)       0         max_pooling3d[0][0]
#                                                                     conv3d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 20, 32, 28, 97)       0         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)            (None, 20, 32, 28, 128)      335360    max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)  (None, 20, 32, 28, 225)      0         max_pooling3d_1[0][0]
#                                                                     conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)            (None, 20, 32, 28, 128)      777728    concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)  (None, 20, 32, 28, 225)      0         max_pooling3d_1[0][0]
#                                                                     conv3d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 10, 16, 14, 225)      0         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)            (None, 10, 16, 14, 256)      1555456   max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)  (None, 10, 16, 14, 481)      0         max_pooling3d_2[0][0]
#                                                                     conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)            (None, 10, 16, 14, 256)      3324928   concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)  (None, 10, 16, 14, 481)      0         max_pooling3d_2[0][0]
#                                                                     conv3d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 5, 8, 7, 481)         0         concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)            (None, 5, 8, 7, 512)         6649856   max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)  (None, 5, 8, 7, 993)         0         max_pooling3d_3[0][0]
#                                                                     conv3d_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)            (None, 5, 8, 7, 512)         13727744  concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)  (None, 5, 8, 7, 993)         0         max_pooling3d_3[0][0]
#                                                                     conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTran (None, 10, 16, 14, 256)      2033920   concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate) (None, 10, 16, 14, 737)      0         conv3d_transpose[0][0]
#                                                                     concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)           (None, 10, 16, 14, 256)      5094400   concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate) (None, 10, 16, 14, 993)      0         concatenate_10[0][0]
#                                                                     conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)           (None, 10, 16, 14, 256)      6863872   concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate) (None, 10, 16, 14, 993)      0         concatenate_10[0][0]
#                                                                     conv3d_11[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTr (None, 20, 32, 28, 128)      1016960   concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate) (None, 20, 32, 28, 353)      0         conv3d_transpose_1[0][0]
#                                                                     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)           (None, 20, 32, 28, 128)      1220096   concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate) (None, 20, 32, 28, 481)      0         concatenate_13[0][0]
#                                                                     conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)           (None, 20, 32, 28, 128)      1662464   concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate) (None, 20, 32, 28, 481)      0         concatenate_13[0][0]
#                                                                     conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTr (None, 40, 64, 56, 64)       246336    concatenate_15[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate) (None, 40, 64, 56, 161)      0         conv3d_transpose_2[0][0]
#                                                                     concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)           (None, 40, 64, 56, 64)       278272    concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate) (None, 40, 64, 56, 225)      0         concatenate_16[0][0]
#                                                                     conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)           (None, 40, 64, 56, 64)       388864    concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate) (None, 40, 64, 56, 225)      0         concatenate_16[0][0]
#                                                                     conv3d_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTr (None, 80, 128, 112, 32)     57632     concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate) (None, 80, 128, 112, 65)     0         conv3d_transpose_3[0][0]
#                                                                     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)           (None, 80, 128, 112, 32)     56192     concatenate_19[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate) (None, 80, 128, 112, 97)     0         concatenate_19[0][0]
#                                                                     conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)           (None, 80, 128, 112, 32)     83840     concatenate_20[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate) (None, 80, 128, 112, 97)     0         concatenate_19[0][0]
#                                                                     conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)           (None, 80, 128, 112, 1)      98        concatenate_21[0][0]
# ==================================================================================================
# Total params: 45,628,226
# Trainable params: 45,628,226
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ------------------------------
# Fitting model...
# ------------------------------
# Epoch 1/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.5063 - accuracy: 0.9030 - val_loss: 0.2159 - val_accuracy: 0.9445
# Epoch 2/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.1503 - accuracy: 0.9459 - val_loss: 0.1128 - val_accuracy: 0.9491
# Epoch 3/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.1081 - accuracy: 0.9536 - val_loss: 0.1060 - val_accuracy: 0.9579
# Epoch 4/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0983 - accuracy: 0.9589 - val_loss: 0.1020 - val_accuracy: 0.9586
# Epoch 5/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.1008 - accuracy: 0.9590 - val_loss: 0.1004 - val_accuracy: 0.9596
# Epoch 6/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.1013 - accuracy: 0.9582 - val_loss: 0.1006 - val_accuracy: 0.9597
# Epoch 7/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0924 - accuracy: 0.9625 - val_loss: 0.0985 - val_accuracy: 0.9625
# Epoch 8/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0893 - accuracy: 0.9632 - val_loss: 0.0965 - val_accuracy: 0.9618
# Epoch 9/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0827 - accuracy: 0.9665 - val_loss: 0.0926 - val_accuracy: 0.9641
# Epoch 10/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0861 - accuracy: 0.9650 - val_loss: 0.0831 - val_accuracy: 0.9677
# Epoch 11/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0839 - accuracy: 0.9664 - val_loss: 0.0905 - val_accuracy: 0.9635
# Epoch 12/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0794 - accuracy: 0.9680 - val_loss: 0.0750 - val_accuracy: 0.9705
# Epoch 13/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0739 - accuracy: 0.9700 - val_loss: 0.0743 - val_accuracy: 0.9715
# Epoch 14/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0757 - accuracy: 0.9693 - val_loss: 0.0741 - val_accuracy: 0.9695
# Epoch 15/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0814 - accuracy: 0.9671 - val_loss: 0.0717 - val_accuracy: 0.9707
# Epoch 16/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0667 - accuracy: 0.9732 - val_loss: 0.0677 - val_accuracy: 0.9721
# Epoch 17/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0752 - accuracy: 0.9689 - val_loss: 0.0662 - val_accuracy: 0.9734
# Epoch 18/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0631 - accuracy: 0.9743 - val_loss: 0.0635 - val_accuracy: 0.9742
# Epoch 19/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0708 - accuracy: 0.9714 - val_loss: 0.0621 - val_accuracy: 0.9750
# Epoch 20/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0605 - accuracy: 0.9756 - val_loss: 0.0606 - val_accuracy: 0.9754
# Epoch 21/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0687 - accuracy: 0.9729 - val_loss: 0.0601 - val_accuracy: 0.9756
# Epoch 22/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0593 - accuracy: 0.9766 - val_loss: 0.0587 - val_accuracy: 0.9762
# Epoch 23/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0615 - accuracy: 0.9749 - val_loss: 0.0620 - val_accuracy: 0.9742
# Epoch 24/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0569 - accuracy: 0.9769 - val_loss: 0.0604 - val_accuracy: 0.9745
# Epoch 25/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0565 - accuracy: 0.9772 - val_loss: 0.0584 - val_accuracy: 0.9768
# Epoch 26/50
# 150/150 [==============================] - 170s 1s/step - loss: 0.0518 - accuracy: 0.9791 - val_loss: 0.0533 - val_accuracy: 0.9785
# Epoch 27/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0507 - accuracy: 0.9798 - val_loss: 0.0531 - val_accuracy: 0.9785
# Epoch 28/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0512 - accuracy: 0.9792 - val_loss: 0.0511 - val_accuracy: 0.9793
# Epoch 29/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0514 - accuracy: 0.9792 - val_loss: 0.0534 - val_accuracy: 0.9789
# Epoch 30/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0507 - accuracy: 0.9795 - val_loss: 0.0517 - val_accuracy: 0.9791
# Epoch 31/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0528 - accuracy: 0.9786 - val_loss: 0.0493 - val_accuracy: 0.9805
# Epoch 32/50
# 150/150 [==============================] - 168s 1s/step - loss: 0.0469 - accuracy: 0.9811 - val_loss: 0.0497 - val_accuracy: 0.9798
# Epoch 33/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0448 - accuracy: 0.9818 - val_loss: 0.0481 - val_accuracy: 0.9806
# Epoch 34/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0491 - accuracy: 0.9802 - val_loss: 0.0466 - val_accuracy: 0.9815
# Epoch 35/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0471 - accuracy: 0.9810 - val_loss: 0.0456 - val_accuracy: 0.9822
# Epoch 36/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0420 - accuracy: 0.9831 - val_loss: 0.0480 - val_accuracy: 0.9810
# Epoch 37/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0421 - accuracy: 0.9832 - val_loss: 0.0453 - val_accuracy: 0.9817
# Epoch 38/50
# 150/150 [==============================] - 168s 1s/step - loss: 0.0368 - accuracy: 0.9853 - val_loss: 0.0433 - val_accuracy: 0.9826
# Epoch 39/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0385 - accuracy: 0.9848 - val_loss: 0.0419 - val_accuracy: 0.9836
# Epoch 40/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0407 - accuracy: 0.9838 - val_loss: 0.0406 - val_accuracy: 0.9836
# Epoch 41/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0356 - accuracy: 0.9859 - val_loss: 0.0406 - val_accuracy: 0.9841
# Epoch 42/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0347 - accuracy: 0.9862 - val_loss: 0.0403 - val_accuracy: 0.9841
# Epoch 43/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0318 - accuracy: 0.9873 - val_loss: 0.0399 - val_accuracy: 0.9841
# Epoch 44/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0324 - accuracy: 0.9871 - val_loss: 0.0401 - val_accuracy: 0.9842
# Epoch 45/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0317 - accuracy: 0.9873 - val_loss: 0.0367 - val_accuracy: 0.9855
# Epoch 46/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0301 - accuracy: 0.9880 - val_loss: 0.0383 - val_accuracy: 0.9852
# Epoch 47/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0276 - accuracy: 0.9890 - val_loss: 0.0358 - val_accuracy: 0.9859
# Epoch 48/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0266 - accuracy: 0.9894 - val_loss: 0.0361 - val_accuracy: 0.9858
# Epoch 49/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0260 - accuracy: 0.9896 - val_loss: 0.0371 - val_accuracy: 0.9854
# Epoch 50/50
# 150/150 [==============================] - 169s 1s/step - loss: 0.0254 - accuracy: 0.9899 - val_loss: 0.0368 - val_accuracy: 0.9859
# ------------------------------
# Training finished
# ------------------------------

# %% [markdown]
# ## 3D-Dense-U-Net预测

# %%
test_cases_folders = sorted(os.listdir(rootPath + SrcmhdFolder + '/ROI/test/images/'))#[0:1]
test_labels_folders = sorted(os.listdir(rootPath + SrcmhdFolder + '/ROI/test/masks/'))#[0:1]

# %%
# 依次加载测试数据集并预测
i = 0
for testfile in test_cases_folders:
    casesPath = rootPath + SrcmhdFolder + '/ROI/test/images/' + testfile + '/*.bin'
    labelsPath = rootPath + SrcmhdFolder + '/ROI/test/masks/' + test_labels_folders[i] + '/*.bin'
    # print(casesPath,labelsPath)
    dataset_test = dataset_test_build(casesPath,labelsPath)

    # 预测测试结果
    weight_dir = os.path.join('weights', '3D-Dense-Unet-Ins-20210922-090830' + '.h5')
    outPath = rootPath + SrcmhdFolder + "/pred_ROI/" + "pred_" + testfile + "/"
    predict(weight_dir,dataset_test,outPath,0.5)
    i = i + 1
# Out:
# ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image011/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image011/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image011/004.bin'] ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image011/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image011/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image011/004.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 1s 518ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 275ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 275ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image012/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image012/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image012/004.bin'] ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image012/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image012/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image012/004.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 500ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 272ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 275ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image013/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image013/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image013/004.bin'] ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image013/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image013/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image013/004.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 1s 529ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 276ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 280ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 275ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image014/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image014/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image014/004.bin'] ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image014/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image014/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image014/004.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 1s 534ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 277ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 275ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 278ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 292ms/step
# ------------------------------
# Prediction finished
# ------------------------------
# ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image015/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image015/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/images/Splt_image015/004.bin'] ['/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image015/002.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image015/003.bin', '/home/shu/Dataset/Dataset-xVertSeg/Spilt/ROI/test/masks/Splt_image015/004.bin']
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 482ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 277ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 273ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 274ms/step
# (1, 80, 128, 112) (1, 80, 128, 112)
# 1/1 [==============================] - 0s 281ms/step
# ------------------------------
# Prediction finished
# ------------------------------

# %% [markdown]
# ## Eval Seg Results

# %%
# 定义评价指标:
EvalDict = {'DICE':0,'JACRD':0,'HDRFDST':0,'ACURCY':0}

# %%
GTROIPath = rootPath + SrcmhdFolder + '/ROI/test/masks/'
predROIPath = rootPath + SrcmhdFolder + '/pred_ROI/'

# %%
GTROIFolders = sorted(os.listdir(GTROIPath))#[4:5]
predROIFolders = sorted(os.listdir(predROIPath))#[4:5]

# %% [markdown]
# ### 获得评价指标对应结果

# %%
i = 0
EvalResultsDatas = []
for GTROIFolder in GTROIFolders:
    GTFolder = GTROIPath + GTROIFolder
    PredFolder = predROIPath + predROIFolders[i] + '/norm'
    
    EvalResultsData = EvalResults(GTFolder,PredFolder,EvalDict)
    EvalResultsData.index = ['L1', 'L2', 'L3', 'L4', 'L5']
    EvalResultsDatas.append(EvalResultsData)
    i+=1
# Out:
# 5 5
#        DICE     JACRD    HDRFDST    ACURCY
# 0  0.883276  0.790952  16.401219  0.991051
# 0  0.847663  0.735604  13.747727  0.987950
# 0  0.902443  0.822229   7.071068  0.991038
# 0  0.884331  0.792646  11.180340  0.987806
# 0  0.879924  0.785594   8.660254  0.987823
# 5 5
#        DICE     JACRD    HDRFDST    ACURCY
# 0  0.870046  0.769983  11.832160  0.987575
# 0  0.881894  0.788740  11.575837  0.987315
# 0  0.882611  0.789887  12.328828  0.987251
# 0  0.882480  0.789678  16.431677  0.987372
# 0  0.855991  0.748238  18.681542  0.983902
# 5 5
#        DICE     JACRD    HDRFDST    ACURCY
# 0  0.893084  0.806821   8.485281  0.988384
# 0  0.919123  0.850349   6.164414  0.990268
# 0  0.905774  0.827777  15.524175  0.987190
# 0  0.860399  0.755001  16.000000  0.984024
# 0  0.859570  0.753724  15.524175  0.979198
# 5 5
#        DICE     JACRD    HDRFDST    ACURCY
# 0  0.819815  0.694650  16.822604  0.976271
# 0  0.809362  0.679772  18.439089  0.974248
# 0  0.904395  0.825476  12.806248  0.986327
# 0  0.910080  0.834996  11.180340  0.987729
# 0  0.850871  0.740449  12.206556  0.978580
# 5 5
#        DICE     JACRD    HDRFDST    ACURCY
# 0  0.847668  0.735611  15.264338  0.988878
# 0  0.894433  0.809027   8.124038  0.990588
# 0  0.855977  0.748217  11.045361  0.987192
# 0  0.829895  0.709248  21.610183  0.985298
# 0  0.855035  0.746778  12.529964  0.985234

# %% [markdown]
# ### 所有椎体的DICE平均值

# %%
ResultsALL = pd.concat(EvalResultsDatas)

# %%
format(ResultsALL.DICE.mean(), '3f')
# Out:
# '0.871446'

# %% [markdown]
# ### Get Dice of L1-L5

# %%
# Get Mean Dice of L1-L5
L1 = []
L2 = []
L3 = []
L4 = []
L5 = []
for EvalResult in EvalResultsDatas:
    
    L1.append(EvalResult.DICE['L1'])
    L2.append(EvalResult.DICE['L2'])
    L3.append(EvalResult.DICE['L3'])
    L4.append(EvalResult.DICE['L4'])
    L5.append(EvalResult.DICE['L5'])

# %%
L = [L1,L2,L3,L4,L5]

# %%
MeanL = []
for L_idx in L:
    MeanL.append(format(np.array(L_idx).mean(), '.4f'))
print(MeanL)
# Out:
# ['0.8628', '0.8705', '0.8902', '0.8734', '0.8603']

# %%
0.8720277999999999
['0.8634', '0.8713', '0.8904', '0.8738', '0.8613']
# Out:
# ['0.8634', '0.8713', '0.8904', '0.8738', '0.8613']
